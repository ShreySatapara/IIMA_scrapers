# %%
curl 'https://www.linkedin.com/voyager/api/feed/comments?count=24&q=comments&sortOrder=RELEVANCE&start=0&updateId=activity%3A6745265082680311808' \
  -H 'authority: www.linkedin.com' \
  -H 'pragma: no-cache' \
  -H 'cache-control: no-cache' \
  -H 'accept: application/vnd.linkedin.normalized+json+2.1' \
  -H 'csrf-token: ajax:8394047485144416831' \
  -H 'x-restli-protocol-version: 2.0.0' \
  -H 'x-li-lang: en_US' \
  -H 'user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36' \
  -H 'x-li-page-instance: urn:li:page:d_flagship3_detail_base;YW064r0MS6uyAwa8gwVJ2A==' \
  -H 'x-li-track: {"clientVersion":"1.8.443","mpVersion":"1.8.443","osName":"web","timezoneOffset":5.5,"timezone":"Asia/Calcutta","deviceFormFactor":"DESKTOP","mpName":"voyager-web","displayDensity":1,"displayWidth":1360,"displayHeight":768}' \
  -H 'sec-fetch-site: same-origin' \
  -H 'sec-fetch-mode: cors' \
  -H 'sec-fetch-dest: empty' \
  -H 'referer: https://www.linkedin.com/feed/update/urn:li:activity:6745265082680311808/?updateEntityUrn=urn%3Ali%3Afs_feedUpdate%3A%28V2%2Curn%3Ali%3Aactivity%3A6745265082680311808%29' \
  -H 'accept-language: en-GB,en-US;q=0.9,en;q=0.8' \
  -H 'cookie: bcookie="v=2&4b7b24e4-7234-47d6-80d3-1cf84128934c"; bscookie="v=1&202009080320272a80615e-734d-417d-8a57-11f9f81ab6beAQHHFXDwwrTJDsF1rn1GUOjlYipLyhns"; lissc=1; _ga=GA1.2.276744237.1599535229; G_ENABLED_IDPS=google; liap=true; JSESSIONID="ajax:8394047485144416831"; li_sugr=dfb0edc9-7f10-4648-8241-ba9e59d782b7; _gcl_au=1.1.1938116686.1601968743; aam_uuid=03788953109956728954426880792397588798; li_oatml=AQGCi-sPVdFgdgAAAXepSskKCHpNKnonHNvDchNF_-exMLrALTICztw581Z8Mq0j47Ad897Xd49kytqrTE8g0jWLUCxGPcqo; timezone=Asia/Calcutta; gpv_pn=www.linkedin.com%2Flearning%2Fnlp-with-python-for-machine-learning-essential-training%2Fwelcome; s_tslv=1613454858014; li_at=AQEDASjHZiYDT8JiAAABdGu6riEAAAF38XxiXE4AVX0ssikJMSbGOZlHvo4nB3Lx387UdaPb-7G6dAYweLvaOiv3HHkcC8-hz0AgTBEM_V5tFRA3ttQa7YjXvnZVgMoypKuG-zOdSHojZdkIJFyyb9fc; lang=v=2&lang=en-us; spectroscopyId=a42f958f-556d-473d-b2f5-fe2cce8de00e; AMCVS_14215E3D5995C57C0A495C55%40AdobeOrg=1; AnalyticsSyncHistory=AQK0CDYX710r5wAAAXfd3JbQGvkbL-A76ED5vq0iS5Sn0XPeMkfv8KCAhnZz1XpJULA-Fqarf162VqYhxxWaEw; lms_ads=AQFNmQm4sTEXawAAAXfd3JkYTXpmqz1qSFtFhhNRLB7alwXzqIExLus1MfxHj6rGwooxpW9D2JxmEYzgNR6m0-Ax4ttS361s; lms_analytics=AQFNmQm4sTEXawAAAXfd3JkYTXpmqz1qSFtFhhNRLB7alwXzqIExLus1MfxHj6rGwooxpW9D2JxmEYzgNR6m0-Ax4ttS361s; _gid=GA1.2.840784386.1614342447; AMCV_14215E3D5995C57C0A495C55%40AdobeOrg=-637568504%7CMCIDTS%7C18684%7CMCMID%7C04000336474427711884440654360387082997%7CMCAAMLH-1614959803%7C12%7CMCAAMB-1614959803%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1614362203s%7CNONE%7CvVersion%7C5.1.1%7CMCCIDH%7C864184511; UserMatchHistory=AQLvxl1kX0vJcwAAAXffYsavmp8YA02wYWXo8bdDI_SvJDwc0uJjSMmLXoKRHYXHEn5zGJMhbyQ2Ki9QYO6fpYCx0u2kdcr3stsrg0h-wxDaSa6HL_fySFp78285WfSHdNVshQm3BhCJ1FTOZyjuv-2kzmU7fw3N17xfatPA30Nqmj2pHnKhQTKBPHy2h6dzmsAUrg7icDsvc7XnWyNAVr8zsLinqrCZehQKskQF--3bvqZ4LVzHMAIOwwxDJEdWAZd3CG1gzbnMP97Wkwp4x4zyU2-QfSX97cafa_ye45nw1zEfRg3-4aGdGHqjh1gXqg; lidc="b=VB54:s=V:r=V:g=3231:u=77:i=1614360531:t=1614446851:v=1:sig=AQHsZjMs8goUCeGaSfNregm8KcxVaO_g"' \
  --compressed

# %%
import json
import requests
from bs4 import BeautifulSoup
import time
import urllib

# %%
initial_url = 'https://www.linkedin.com/voyager/api/feed/comments?count='
url_param = '&q=comments&sortOrder=RELEVANCE&start=0&updateId=activity'

initial_referer = 'https://www.linkedin.com/feed/update/urn:li:activity:6745265082680311808/?updateEntityUrn'
initial_header = {'authority': 'www.linkedin.com',
'pragma': 'no-cache',
'cache-control': 'no-cache',
'accept': 'application/vnd.linkedin.normalized+json+2.1',
'csrf-token': 'ajax:8394047485144416831',
'x-restli-protocol-version': '2.0.0',
'x-li-lang': 'en_US',
'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36',
'x-li-page-instance': 'urn:li:page:d_flagship3_detail_base;YW064r0MS6uyAwa8gwVJ2A==',
'x-li-track': '{"clientVersion":"1.8.443","mpVersion":"1.8.443","osName":"web","timezoneOffset":5.5,"timezone":"Asia/Calcutta","deviceFormFactor":"DESKTOP","mpName":"voyager-web","displayDensity":1,"displayWidth":1360,"displayHeight":768}',
'sec-fetch-site': 'same-origin',
'sec-fetch-mode': 'cors',
'sec-fetch-dest': 'empty',
'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
'cookie': 'bcookie="v=2&4b7b24e4-7234-47d6-80d3-1cf84128934c"; bscookie="v=1&202009080320272a80615e-734d-417d-8a57-11f9f81ab6beAQHHFXDwwrTJDsF1rn1GUOjlYipLyhns"; lissc=1; _ga=GA1.2.276744237.1599535229; G_ENABLED_IDPS=google; liap=true; JSESSIONID="ajax:8394047485144416831"; li_sugr=dfb0edc9-7f10-4648-8241-ba9e59d782b7; _gcl_au=1.1.1938116686.1601968743; aam_uuid=03788953109956728954426880792397588798; li_oatml=AQGCi-sPVdFgdgAAAXepSskKCHpNKnonHNvDchNF_-exMLrALTICztw581Z8Mq0j47Ad897Xd49kytqrTE8g0jWLUCxGPcqo; timezone=Asia/Calcutta; gpv_pn=www.linkedin.com%2Flearning%2Fnlp-with-python-for-machine-learning-essential-training%2Fwelcome; s_tslv=1613454858014; li_at=AQEDASjHZiYDT8JiAAABdGu6riEAAAF38XxiXE4AVX0ssikJMSbGOZlHvo4nB3Lx387UdaPb-7G6dAYweLvaOiv3HHkcC8-hz0AgTBEM_V5tFRA3ttQa7YjXvnZVgMoypKuG-zOdSHojZdkIJFyyb9fc; lang=v=2&lang=en-us; spectroscopyId=a42f958f-556d-473d-b2f5-fe2cce8de00e; AMCVS_14215E3D5995C57C0A495C55%40AdobeOrg=1; AnalyticsSyncHistory=AQK0CDYX710r5wAAAXfd3JbQGvkbL-A76ED5vq0iS5Sn0XPeMkfv8KCAhnZz1XpJULA-Fqarf162VqYhxxWaEw; lms_ads=AQFNmQm4sTEXawAAAXfd3JkYTXpmqz1qSFtFhhNRLB7alwXzqIExLus1MfxHj6rGwooxpW9D2JxmEYzgNR6m0-Ax4ttS361s; lms_analytics=AQFNmQm4sTEXawAAAXfd3JkYTXpmqz1qSFtFhhNRLB7alwXzqIExLus1MfxHj6rGwooxpW9D2JxmEYzgNR6m0-Ax4ttS361s; _gid=GA1.2.840784386.1614342447; AMCV_14215E3D5995C57C0A495C55%40AdobeOrg=-637568504%7CMCIDTS%7C18684%7CMCMID%7C04000336474427711884440654360387082997%7CMCAAMLH-1614959803%7C12%7CMCAAMB-1614959803%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1614362203s%7CNONE%7CvVersion%7C5.1.1%7CMCCIDH%7C864184511; UserMatchHistory=AQLvxl1kX0vJcwAAAXffYsavmp8YA02wYWXo8bdDI_SvJDwc0uJjSMmLXoKRHYXHEn5zGJMhbyQ2Ki9QYO6fpYCx0u2kdcr3stsrg0h-wxDaSa6HL_fySFp78285WfSHdNVshQm3BhCJ1FTOZyjuv-2kzmU7fw3N17xfatPA30Nqmj2pHnKhQTKBPHy2h6dzmsAUrg7icDsvc7XnWyNAVr8zsLinqrCZehQKskQF--3bvqZ4LVzHMAIOwwxDJEdWAZd3CG1gzbnMP97Wkwp4x4zyU2-QfSX97cafa_ye45nw1zEfRg3-4aGdGHqjh1gXqg; lidc="b=VB54:s=V:r=V:g=3231:u=77:i=1614360531:t=1614446851:v=1:sig=AQHsZjMs8goUCeGaSfNregm8KcxVaO_g"'}

def create_valid_header(header,id_,initial_referer):
    original_param = '=urn:li:fs_feedUpdate:(V2,urn:li:activity:'+ str(id_) + ')'
    encoded_param = urllib.parse.quote(original_param)
    referer_encoded = initial_referer + encoded_param
    referer = initial_referer + referer_encoded
    header['referer'] = referer
    return header

def create_valid_url(data,id_):
    numComments = data[id_]['numComments']
    id_ = ':'+str(id_)
    encoded_id = urllib.parse.quote(id_)
    url = initial_url + str(numComments) + url_param + encoded_id
    #print(url)
    return url

def get_comments(header,url):
    try:
        req = requests.get(url, headers = header).text
        req = json.loads(req)
        comments = []
        for comment in req['included']:
            if 'commentV2' in comment:
                text = comment['commentV2']['text']
                comments.append(text)
        print('success' ,end = '')
    except:
        print('err')
    time.sleep(10)
    return comments

# %%
file = open('linkedin_data__134.json')
data = json.load(file)
counter = 0
for id_ in data:
    header = create_valid_header(initial_header,id_,initial_referer)
    url = create_valid_url(data,id_)
    comments = get_comments(header,url)
    data[id_]['comments'] = comments
    print(counter)
    counter+=1
    if(counter%20==0):
      with open('linkedin_data_with_comments.json', 'w') as outfile:
        json.dump(data, outfile)
        print()
        print('=============================================================')
        print('saved upto '+ str(counter))
        print('=============================================================')
        print()
# Out:
# success0
# success1
# success2
# success3
# success4
# success5
# success6
# success7
# success8
# success9
# success10
# success11
# success12
# success13
# success14
# success15
# success16
# success17
# success18
# success19
#
# ...
# saved upto 20
# ...
#
# success20
# success21
# success22
# success23
# success24
# success25
# success26
# success27
# success28
# success29
# success30
# success31
# success32
# success33
# success34
# success35
# success36
# success37
# success38
# success39
#
# ...
# saved upto 40
# ...
#
# success40
# success41
# success42
# success43
# success44
# success45
# success46
# success47
# success48
# success49
# success50
# success51
# success52
# success53
# success54
# success55
# success56
# success57
# success58
# success59
#
# ...
# saved upto 60
# ...
#
# success60
# success61
# success62
# success63
# success64
# success65
# success66
# success67
# success68
# success69
# success70
# success71
# success72
# success73
# success74
# success75
# success76
# success77
# success78
# ...

# %%
data
# Out:
# {'6643499950443458561': {'comments': ['❌❌❌', 'Excellent'],
#   'numComments': 2,
#   'numLikes': 336,
#   'reactions': {'LIKE': 331, 'MAYBE': 2, 'PRAISE': 3},
#   'title': '#Amul Topical: Jyotiraditya shifts allegiances!',
#   'url': 'https://www.linkedin.com/feed/update/urn:li:activity:6643499950443458561?updateEntityUrn=urn%3Ali%3Afs_feedUpdate%3A%28V2%2Curn%3Ali%3Aactivity%3A6643499950443458561%29'},
#  '6644216751871619072': {'comments': ['Nice',
#    "Namaste is best. Amul trying to be Secular. I understand. It's about business.",
#    'Nice one!',
#    'Nice',
#    'Very Funny',
#    'Good',
#    'any job in Kolkata for sales executive'],
#   'numComments': 7,
#   'numLikes': 495,
#   'reactions': {'EMPATHY': 9, 'LIKE': 479, 'PRAISE': 7},
#   'title': '#Amul Topical: Owing to Coronavirus, Indian greeting goes global...',
# ...

# %%
with open('linkedin_data_with_comments.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
data = open('linkedin_data_with_comments.json')
data = json.load(data)

# %%
len(data)
# Out:
# 134

# %%
counter = 0
for unit in data:
  if(data[unit]['numComments']!=len(data[unit]['comments'])):
    print(unit)
    counter+=1
print()
print(counter)
# Out:
# 6762024278822055936
# 6762685992236331008
# 6768452383694495745
# 6768032863926521856
# 6764024957707051008
# 6753247903424266240
# 6766564184642637824
# 6765672446566699008
# 6746103141579718656
# 6767706953528467456
# 6764777539182374912
# 6734022960954310656
# 6731161018921230336
# 6716601301918126081
# 6709285047746252800
# 6706016346909544448
# 6705090548010668032
# 6707285726247088128
# 6699314433467977728
# 6688792113385218050
# 6683719083197767680
# 6685067654618759168
# 6679393724470038528
# 6673875307977691136
# 6678666421934944256
#
# 25

# %%
for unit in data:
